# %% [markdown]
# # Dependencias

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import entropy
import cv2
import os
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
import pickle 
from sklearn.model_selection import cross_val_score
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Entrenamiento

# %% [markdown]
# ## Parámetros

# %%
# distancia de comparación entre pixeles
distancia = 8
# tamaño de la ventana
n = 32
# angulo de comparaciones
angulo = [0, 45, 90]
# blur
blur = 31

gb_x = 51 
gb_y = 51 
gb_s = 0

escala = 256

# %% [markdown]
# ## Funciones para generar los datos de prueba

# %% [markdown]
# ### Para GLCM

# %%
def GLCM(matriz,distancia,angulo,escala):
  '''
  matriz: matriz inicial
  distancia: distancia de movimiento 
  angulo: ángulo
  escala: tamaño de la matriz de co-ocurrencia
  '''
  glcm = np.zeros((escala,escala))
  width, height = matriz.shape 
  for x in range(width):
    for y in range(height):
      if 0 in angulo:#Dirección 0 °
        if y+distancia < height: # Verificación fuera de límites 
          glcm[matriz[x][y]][matriz[x][y+distancia]] += 1

      if 45 in angulo:
        if (x-distancia) >= 0 and 0 < y-distancia:# Verificación fuera de límites
          glcm[matriz[x][y]][matriz[x-distancia][y-distancia]] += 1
                  
      if 90 in angulo: # Verificación fuera de límites
        if x+distancia < width:
          glcm[matriz[x][y]][matriz[x+distancia][y]] += 1

      if 135 in angulo:
        if (y-distancia) >= 0 and x+distancia < width: # Verificación fuera de límites  
          glcm[matriz[x][y]][matriz[x+distancia][y-distancia]] += 1
    #Verificar si la matriz es simetrica 
  if np.array_equal(glcm, glcm.T):
    glcm=glcm+glcm.T

  vector = vectorizar(glcm.astype("int32"))
  del glcm
  return vector

# %%
def vectorizar(glcm):
  '''Toma una matriz y genera el vector que describe a esa matriz'''
  var = glcm.var()
  mean = glcm.mean()
  std = glcm.std()

  glcm_h = glcm.reshape((-1,1))
  h = entropy(glcm_h, base=2)

  return [mean, var, std, h[0]]

# %% [markdown]
# ### Funciones para generar los datos

# %%
def generar_pruebas(imagen, distancia, angulo, escala, tamaño_x, tamaño_y=None, n=None):
  '''Genera las ventanas de pixeles. Se generan ventanas interpoladas a la mitad
  Parámetros
  imagen: Matriz de la imágen
  distancia: Distancia de comparación entre pixeles
  tamaño_x: tamaño de la imágen en X
  tamaño_y: tamaño de la imágen en Y
  n: tamaño de la ventana
  '''
  if n==None:
    n = distancia*2+1

  if tamaño_y==None:
    tamaño_y=tamaño_x
  
  ventanas = list()
  
  for i in range(0,tamaño_x-n,distancia):
    for j in range(0,tamaño_y-n,distancia):
      # Genera la ventana
      matriz = imagen[i:i+n,j:j+n,:] 
      # Encontramos la suma de la matriz ponderada
      suma = np.sum(matriz)
      # Si la ponderación es diferente a 0, se agrega
      if suma > 100:
        R_GLCM = GLCM(matriz[:,:,0], distancia, angulo, escala)
        G_GLCM = GLCM(matriz[:,:,1], distancia, angulo, escala)
        B_GLCM = GLCM(matriz[:,:,2], distancia, angulo, escala)

        ventanas.append(np.array(R_GLCM+G_GLCM+B_GLCM))
        del R_GLCM
        del G_GLCM
        del B_GLCM
      del matriz
      
  return ventanas

def etiquetar(lista_muestras, etiqueta):
  '''Etiqueta un conjunto de muestras'''
  return [(x, etiqueta) for x in lista_muestras]

# %%
def sacar_pruebas(url, distancia, n, angulo, etiqueta):
  print("Leyendo Imagen",url.split("/")[-1])
  # cargamos la imágen
  img = cv2.imread(url)
  img = cv2.cvtColor( aplicar_blur(img, gb_x, gb_y, gb_s) , cv2.COLOR_BGR2RGB)

  # establecemos el valor posible de pixeles
  escala = 256

  # Se generan las pruebas
  lista_pruebas_vectores = generar_pruebas(img, distancia, angulo, escala,
                                          img.shape[0], img.shape[1], n)

  # etiquetamos los vectores
  lista_pruebas_vectores_etiquetados = etiquetar(lista_pruebas_vectores, etiqueta)

  return lista_pruebas_vectores_etiquetados

# %%
def sacar_pruebas_normalizadas(url, distancia, n, angulo):
  print("Leyendo Imagen",url.split("/")[-1])

  # Sacamos las imagenes normalizadas
  sargazo, no_sargazo = imagenes_normalizadas(url)

  # establecemos el valor posible de pixeles
  escala = 256

  # Se generan las pruebas para sargazo
  pruebas_sargazo = generar_pruebas(sargazo, distancia, angulo, escala,
                                    sargazo.shape[0], sargazo.shape[1], n)

  # etiquetamos los vectores
  sargazo_etiquetado = etiquetar(pruebas_sargazo, 1)

  # Se generan las pruebas para no sargazo
  pruebas_no_sargazo = generar_pruebas(no_sargazo, distancia, angulo, escala,
                                      no_sargazo.shape[0], no_sargazo.shape[1], n)

  # etiquetamos los vectores
  no_sargazo_etiquetado = etiquetar(pruebas_no_sargazo, 0)

  return sargazo_etiquetado+no_sargazo_etiquetado

def imagenes_normalizadas(img_url):

  url_sargazo = img_url.split(".")[0]+"S.png"
  url_no_sargazo = img_url.split(".")[0]+"N.png"

  imagen = cv2.imread(img_url)
  imagen = cv2.cvtColor( aplicar_blur(imagen, gb_x, gb_y, gb_s), cv2.COLOR_BGR2RGB)

  new_imagen = np.zeros_like(imagen)
  #Se recorren filas y columnas para obtener el pixel cuyo valor se más pequeñ
      #para establecer el nuevo origen.  
  for f in range(imagen.shape[0]):
    new_imagen[f,:,0] = imagen[f,:,0] - np.min(imagen[f,:,0])
    new_imagen[f,:,1] = imagen[f,:,1] - np.min(imagen[f,:,1])
    new_imagen[f,:,2] = imagen[f,:,2] - np.min(imagen[f,:,2])

  for c in range(imagen.shape[1]):
    new_imagen[:,c,0] = imagen[:,c,0] - np.min(imagen[:,c,0])
    new_imagen[:,c,1] = imagen[:,c,1] - np.min(imagen[:,c,1])
    new_imagen[:,c,2] = imagen[:,c,2] - np.min(imagen[:,c,2])
   
  img_sargazo = cv2.cvtColor( cv2.imread(url_sargazo) , cv2.COLOR_BGR2RGB)
  #La imagen con el nuevo origen es multiplicada por los 
      #pixeles diferentes de cero en la máscara de sargazo con blur
  sargazo = new_imagen * (img_sargazo != 0) 
  del img_sargazo

  img_no_sargazo = cv2.cvtColor( cv2.imread(url_no_sargazo) , cv2.COLOR_BGR2RGB)
  #La imagen con el nuevo origen es multiplicada por los 
      #pixeles diferentes de cero en la máscara de sin sargazo con blur
  no_sargazo = new_imagen * (img_no_sargazo != 0)
  del img_no_sargazo

  return sargazo, no_sargazo

# %%
imagen = cv2.imread("/content/drive/MyDrive/Aux/Mascaras/18.png")
imagen = cv2.cvtColor( aplicar_blur(imagen, gb_x, gb_y, gb_s) , cv2.COLOR_BGR2RGB)
imagen = normalizar(imagen)

# %%
plt.imshow(imagen)

# %%
mascara = cv2.imread("/content/drive/MyDrive/Aux/Mascaras/18S.png")
mascara = cv2.cvtColor( aplicar_blur(mascara, gb_x, gb_y, gb_s) , cv2.COLOR_BGR2RGB)

# %%
plt.imshow(mascara)

# %%
sargazo = imagen * (mascara != 0)

# %%
plt.imshow(sargazo)

# %%
def aplicar_blur(img, gb_x, gb_y=None, gb_s=0):
  if gb_x%2 != 1:
    gb_x += 1
  if gb_y is None:
    gb_y = gb_x
  elif gb_y%2 != 1:
    gb_y += 1

  return cv2.GaussianBlur(img,(gb_x,gb_y),gb_s)

# %% [markdown]
# ## Generar datos de prueba

# %% [markdown]
# ### Generación de datos de prueba (Mascaras Normalizadas)

# %%
PATH = "/content/drive/MyDrive/Aux/Mascaras/"
texturas_url = list()
for imagen in os.listdir(PATH):
  if ( not imagen.endswith("S.png") ) and ( not imagen.endswith("N.png")) and ( not imagen.endswith("pickle")):
    texturas_url.append(PATH+imagen)

# %%
train_set = [sacar_pruebas_normalizadas(url, distancia=distancia, n=n, 
                                     angulo=angulo) 
                  for url in texturas_url]
# Out:
# Leyendo Imagen 1.png
# Leyendo Imagen 2.png
# Leyendo Imagen 3.png
# Leyendo Imagen 4.png
# Leyendo Imagen 5.png
# Leyendo Imagen 6.png
# Leyendo Imagen 7.png
# Leyendo Imagen 8.png
# Leyendo Imagen 9.png
# Leyendo Imagen 10.png
# Leyendo Imagen 11.png
# Leyendo Imagen 12.png
# Leyendo Imagen 13.png
# Leyendo Imagen 14.png
# Leyendo Imagen 15.png
# Leyendo Imagen 16.png
# Leyendo Imagen 17.png
# Leyendo Imagen 18.png
# Leyendo Imagen 19.png
# Leyendo Imagen 20.png
# Leyendo Imagen 21.png
# Leyendo Imagen 22.png
# Leyendo Imagen 23.png

# %% [markdown]
# ### Generación de X, Y

# %%
# encadenamos las pruebas para hacer solo una lista full
train_set_new = list()
for lista in train_set:
  train_set_new.extend(lista)
train_set = train_set_new

# %%
#np.random.shuffle(train_set)

# %%
X = np.array([x[0] for x in train_set])
Y = np.array([x[1] for x in train_set])
del train_set

# %%
def guardar(nombre,datos):
  with open(nombre+'.pickle', 'wb') as f:
    pickle.dump(datos, f)

# %%
guardar(PATH+"X_dos_clases_norm",X)
guardar(PATH+"Y_dos_clases_norm",Y)

# %% [markdown]
# ## Entrenamiento de los modelos

# %% [markdown]
# ### Modelos

# %%
def cargar(nombre):
  with open(nombre+'.pickle', 'rb') as f:
    entry = pickle.load(f)
  
  return entry

PATH = "/content/drive/MyDrive/Aux/Mascaras/"
X = cargar(PATH+"X_dos_clases_norm")
Y = cargar(PATH+"Y_dos_clases_norm")

# %% [markdown]
# #### Clasificador Bayesiano **(Naive Bayes)**

# %%
bayes = MultinomialNB()
bayes.fit(X, Y)
# Out:
# MultinomialNB()

# %% [markdown]
# #### Clasificador K vecinos más cercanos **(K nearest neighbours)**

# %%
knn = KNeighborsClassifier(n_neighbors=4)
knn.fit(X, Y)
# Out:
# KNeighborsClassifier(n_neighbors=4)

# %%
knn2 = KNeighborsClassifier(n_neighbors=2)
knn2.fit(X, Y)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %% [markdown]
# #### Clasificador Regresión logística

# %%
LR = LogisticRegression(max_iter=10000)
LR.fit(X, Y)
# Out:
# LogisticRegression(max_iter=10000)

# %% [markdown]
# # Resultados

# %% [markdown]
# ## Función para hacer las pruebas

# %%
def generar_prediccion(imagen, distancia, tam_x, angulo, escala, clasificador, tam_y=None, n=None):
  '''Genera la imagen predicha

  Parámetros
  imagen: Matriz de la imágen
  distancia: Distancia de comparación entre pixeles
  tam_x: tamaño de la imágen en X
  escala: valor máximo de cada pixel
  clasificador: clasificador 
  tam_y: tamaño de la imágen en Y
  n: tamaño de la ventana
  '''
  if n==None:
    n = distancia*2+1

  if tam_y==None:
    tam_y=tam_x

  nuevaimagen = np.zeros((tam_x, tam_y))

  for i in range(0,tam_x-n,distancia):
    for j in range(0,tam_y-n,distancia):
      matriz = imagen[i:i+n,j:j+n,:]

      R_GLCM = GLCM(matriz[:,:,0], distancia, angulo, escala)
      G_GLCM = GLCM(matriz[:,:,1], distancia, angulo, escala)
      B_GLCM = GLCM(matriz[:,:,2], distancia, angulo, escala)

      Vector_Prediccion = np.array([R_GLCM+G_GLCM+B_GLCM])

      Solucion=clasificador.predict(Vector_Prediccion)

      nuevaimagen[i:i+n,j:j+n]=int(Solucion[0])

  resultado = nuevaimagen == 1
  return resultado

# %%
def normalizar(imagen):
  new_imagen = np.zeros_like(imagen)
  for f in range(imagen.shape[0]):
    new_imagen[f,:,0] = imagen[f,:,0] - np.min(imagen[f,:,0])
    new_imagen[f,:,1] = imagen[f,:,1] - np.min(imagen[f,:,1])
    new_imagen[f,:,2] = imagen[f,:,2] - np.min(imagen[f,:,2])

  for c in range(imagen.shape[1]):
    new_imagen[:,c,0] = imagen[:,c,0] - np.min(imagen[:,c,0])
    new_imagen[:,c,1] = imagen[:,c,1] - np.min(imagen[:,c,1])
    new_imagen[:,c,2] = imagen[:,c,2] - np.min(imagen[:,c,2])

  return new_imagen

# %%
def prediccion(imagen, model):
  res = generar_prediccion(imagen, distancia=distancia, tam_x=imagen.shape[0], 
                           tam_y=imagen.shape[1], angulo=angulo, escala=escala, 
                           clasificador=model, n=n)
  figure, axis = plt.subplots(1,3, figsize=(20,40))
  pixeles_sargazo = np.sum(res)
  print("INFORMACIÓN:")
  print("PIXELES CLASIFICADOS COMO SARGAZO:",pixeles_sargazo)
  print("PORCENTAGE DE SARGAZO:",round( (pixeles_sargazo/(imagen.shape[0]*imagen.shape[1]))*100 ,2),"%")
  axis[0].imshow(imagen)
  axis[0].set_title("Original")
  axis[1].imshow(res, cmap="gray")
  axis[1].set_title("Resultado")
  axis[2].imshow(imagen * res.reshape( (res.shape[0],res.shape[1],1) ))
  axis[2].set_title("Enmascarado")
  for i in range(3):
    axis[i].set_yticklabels([])
    axis[i].set_xticklabels([])
  plt.show()

# %% [markdown]
# ## Resultados

# %%
imagen = cv2.imread("/content/drive/MyDrive/Aux/Mascaras/18.png")
imagen = cv2.cvtColor( aplicar_blur(imagen, gb_x, gb_y, gb_s) , cv2.COLOR_BGR2RGB)
imagen = normalizar(imagen)
imagen2 = cv2.imread("/content/drive/MyDrive/Aux/Mascaras/15.png")
imagen2 = cv2.cvtColor( aplicar_blur(imagen2, gb_x, gb_y, gb_s) , cv2.COLOR_BGR2RGB)
imagen2 = normalizar(imagen2)

# %% [markdown]
# ### Imagen 1

# %%
prediccion(imagen, bayes)
# Out:
# INFORMACIÓN:
# PIXELES CLASIFICADOS COMO SARGAZO: 47040
# PORCENTAGE DE SARGAZO: 3.83 %

# %%
prediccion(imagen, knn)
# Out:
# INFORMACIÓN:
# PIXELES CLASIFICADOS COMO SARGAZO: 50752
# PORCENTAGE DE SARGAZO: 4.13 %

# %%
prediccion(imagen, knn2)
# Out:
# INFORMACIÓN:
# PIXELES CLASIFICADOS COMO SARGAZO: 46720
# PORCENTAGE DE SARGAZO: 3.8 %

# %%
prediccion(imagen, LR)
# Out:
# INFORMACIÓN:
# PIXELES CLASIFICADOS COMO SARGAZO: 320
# PORCENTAGE DE SARGAZO: 0.03 %

# %% [markdown]
# ### Imagen 2

# %%
prediccion(imagen2, bayes)
# Out:
# INFORMACIÓN:
# PIXELES CLASIFICADOS COMO SARGAZO: 84608
# PORCENTAGE DE SARGAZO: 6.89 %

# %%
prediccion(imagen2, knn)
# Out:
# INFORMACIÓN:
# PIXELES CLASIFICADOS COMO SARGAZO: 88960
# PORCENTAGE DE SARGAZO: 7.24 %

# %%
prediccion(imagen2, knn2)
# Out:
# INFORMACIÓN:
# PIXELES CLASIFICADOS COMO SARGAZO: 80064
# PORCENTAGE DE SARGAZO: 6.52 %

# %%
prediccion(imagen2, LR)
# Out:
# INFORMACIÓN:
# PIXELES CLASIFICADOS COMO SARGAZO: 14208
# PORCENTAGE DE SARGAZO: 1.16 %

# %% [markdown]
# ### Imagen de prueba

# %%
imagen_prueba = cv2.imread("/content/drive/MyDrive/Aux/Mascaras/prueba1.png")
imagen_prueba = cv2.cvtColor( aplicar_blur(imagen_prueba, gb_x, gb_y, gb_s) , cv2.COLOR_BGR2RGB)

# %%
prediccion(imagen_prueba, knn)
# Out:
# INFORMACIÓN:
# PIXELES CLASIFICADOS COMO SARGAZO: 103744
# PORCENTAGE DE SARGAZO: 8.44 %

# %%
prediccion(imagen_prueba, knn2)
# Out:
# INFORMACIÓN:
# PIXELES CLASIFICADOS COMO SARGAZO: 98496
# PORCENTAGE DE SARGAZO: 8.02 %

# %%
prediccion(imagen_prueba, LR)
# Out:
# INFORMACIÓN:
# PIXELES CLASIFICADOS COMO SARGAZO: 122624
# PORCENTAGE DE SARGAZO: 9.98 %

# %% [markdown]
# ### Imagen prueba Normalizada

# %%
imagen_prueba_2 = normalizar(imagen_prueba)

# %%
prediccion(imagen_prueba_2, knn)
# Out:
# INFORMACIÓN:
# PIXELES CLASIFICADOS COMO SARGAZO: 29760
# PORCENTAGE DE SARGAZO: 2.42 %

# %%
prediccion(imagen_prueba_2, knn2)
# Out:
# INFORMACIÓN:
# PIXELES CLASIFICADOS COMO SARGAZO: 26112
# PORCENTAGE DE SARGAZO: 2.12 %

# %%
prediccion(imagen_prueba_2, LR)
# Out:
# INFORMACIÓN:
# PIXELES CLASIFICADOS COMO SARGAZO: 29888
# PORCENTAGE DE SARGAZO: 2.43 %

# %% [markdown]
# ## Validación

# %%
def validar(modelo, X, Y):
  cv_NB = cross_val_score(modelo, X, Y, cv = 4)
  print("Media de los 4 resultados:", round(np.mean(cv_NB)*100,2),"%" )
  print("Score:",round(modelo.score(X,Y)*100,2),"%")

# %%
validar(bayes, X, Y)
# Out:
# Media de los 4 resultados: 78.23 %
# Score: 78.44 %

# %%
validar(knn, X, Y)
# Out:
# Media de los 4 resultados: 92.27 %
# Score: 95.36 %

# %%
validar(knn2, X, Y)
# Out:
# Media de los 4 resultados: 91.78 %
# Score: 96.19 %

# %%
validar(LR, X, Y)
# Out:
# Media de los 4 resultados: 87.92 %
# Score: 88.09 %
